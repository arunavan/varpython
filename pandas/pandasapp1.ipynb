# %% [markdown]
# * sample *

# %% [markdown]
# ***
# Sample
# ***

# %% [markdown]
# ***Markdown Formatting***
#
# **This is read series using pandas library**
#
# *** Sample pandas example generating series ***
# ***
# sample line
#
# ***
#
# For example, the following syntax:
# Our program website can be found at <a href="http://earthdatascience.org" target="_blank">this link</a>.

# %%
import pandas as pd
a = [1, 7, 2,2,3,4,5,6,7]
myvar = pd.Series(a)

print(myvar)
# Out:
# 0    1
# 1    7
# 2    2
# 3    2
# 4    3
# 5    4
# 6    5
# 7    6
# 8    7
# dtype: int64

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('XEmptEx-dZQ', width=500, height=300)

# %% [markdown]
# 1.pandas
# 2.numpy
# 3.oops
